# %% [markdown]
# <a href="https://colab.research.google.com/github/faiza-hossain/machine-learning-fundamentals/blob/main/02_pandas_profiling_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ydata-profiling

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %%
df=pd.read_csv("https://raw.githubusercontent.com/faiza-hossain/bangladesh-weather-pipeline/refs/heads/main/bangladesh_weather_2016_2025.csv")
profile=ProfileReport(df)
profile.to_notebook_iframe()
