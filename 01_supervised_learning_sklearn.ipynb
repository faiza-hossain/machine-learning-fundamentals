# %% [markdown]
# <a href="https://colab.research.google.com/github/faiza-hossain/machine-learning-fundamentals/blob/main/01_supervised_learning_sklearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
